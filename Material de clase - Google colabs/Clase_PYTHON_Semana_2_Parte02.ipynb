# %% [markdown]
# ## **TEMA 01 - Uso de la herramienta Turtle Graphics**

# %% [markdown]
# El módulo turtle de Python permite dibujar de forma gráfica moviendo una "tortuga" sobre una ventana, como si fuera un lápiz que traza líneas.
# Se usa mucho para aprender programación visualmente.

# %%
import turtle

# Crear la ventana y la tortuga
t = turtle.Turtle()

# Dibujar un cuadrado
for _ in range(4):
    t.forward(100)  # avanza 100 pasos
    t.right(90)     # gira 90 grados

turtle.done()

# %% [markdown]
# La tortuga avanza (forward), retrocede (backward), gira (right, left), cambia color, grosor, etc.

# %% [markdown]
# **Ejemplos Extra:**

# %%
#DIBUJAR UN CIRCULO

import turtle

t = turtle.Turtle()
t.circle(100)  # radio de 100

turtle.done()

# %%
#DIBUJAR UNA ESTRELLA

import turtle

t = turtle.Turtle()

for _ in range(5):
    t.forward(200)
    t.right(144)

turtle.done()

# %% [markdown]
# ##**TEMA 02 - Expresiones regulares y metacaracteres en Python (re)**

# %% [markdown]
# Una expresión regular (abreviada como regex) es una cadena de texto especial que define un patrón de búsqueda.
#
# > Sirve para buscar, validar, extraer o reemplazar fragmentos de texto que cumplen ciertas reglas.
#
# * En lugar de buscar texto exacto, las expresiones regulares permiten decir:
#
# * "Quiero cualquier número de 3 dígitos".
#
# * "Quiero una palabra que empiece con mayúscula".
#
# * "Quiero todas las direcciones de correo dentro de este texto".

# %% [markdown]
# **Ejemplos cotidianos**

# %% [markdown]
# **Validar un número de teléfono**
#
# * Expresión regular: \d{3}-\d{4}
#
# * **Significado:** tres números, guion, cuatro números.
#
# * Texto: "Llama al 555-1234" ✅ coincide.
# ---
# **Encontrar correos electrónicos**
#
# * Expresión regular: \w+@\w+\.\w+
#
# * Texto: "Escribe a prueba@gmail.com" ✅ coincide.
# ---
# **Buscar todas las palabras que empiezan con mayúscula**
#
# * Expresión regular: \b[A-Z]\w*
#
# * Texto: "Hola mundo, Soy estudiante del SIC" → ✅ encuentra "Hola", "Soy", "SIC".

# %% [markdown]
# ---

# %% [markdown]
# ### **Modulo re**

# %% [markdown]
# El módulo re permite buscar, validar y extraer texto usando expresiones regulares (regex).
#
# **Funciones importantes:**
#
# * re.search(patron, texto) → Busca la primera coincidencia.
#
# * re.findall(patron, texto) → Devuelve todas las coincidencias en una lista.
#
# * re.match(patron, texto) → Solo busca al inicio del texto.
#
# * re.split(patron, texto) → Divide un texto en partes.
#
# * re.sub(patron, reemplazo, texto) → Reemplaza coincidencias.
# ---
# **Métodos de los objetos encontrados:**
#
# * .group() → Devuelve el texto encontrado.
#
# * .start() → Índice donde inicia la coincidencia.
#
# * .end() → Índice donde termina.
#
# * .span() → Tupla (inicio, fin).

# %%
import re

texto = "Mis correos son test1@gmail.com y ejemplo123@yahoo.com"

# Buscar todos los correos
patron = r"\w+@\w+\.\w+"
coincidencias = re.findall(patron, texto)

print(coincidencias)
# Out:
# ['test1@gmail.com', 'ejemplo123@yahoo.com']

# %%
import re

texto = "Teléfonos: 123-456, 987-654, 555-111"
patron = r"\d{3}-\d{3}"

print(re.findall(patron, texto))
# Out:
# ['123-456', '987-654', '555-111']

# %%
import re

texto = "Hola123, chau456"

# Buscar todos los números
print(re.findall(r"\d+", texto))  #un metacaracter que significa "uno o más dígitos seguidos".
# 👉 ['123', '456']

# Buscar todas las palabras
print(re.findall(r"\w+", texto))  #un metacaracter que significa "una palabra compuesta de letras/números".
# 👉 ['Hola123', 'chau456']

# %%
import re

text = 'please call 010-2345-1234'
regex = re.compile('(\d{3})-(\d{4}-\d{4})')
match_obj = regex.search(text)

print(match_obj.group())   # 010-2345-1234
print(match_obj.group(1))  # 010
print(match_obj.group(2))  # 2345-1234

# %% [markdown]
# ¿Qué pasa aquí?
#
# \d{3} → encuentra 3 dígitos (010)
#
# \d{4} → encuentra 4 dígitos (2345 y 1234)
#
# Los paréntesis () crean grupos para separar coincidencias.
#
# .group(0) o .group() → el match completo → "010-2345-1234"
#
# .group(1) → primer grupo → "010"
#
# .group(2) → segundo grupo → "2345-1234"

# %% [markdown]
# ---

# %% [markdown]
# ###**Que es un metacaracter?**

# %% [markdown]
# Un metacaracter es un símbolo especial dentro de las expresiones regulares que no representa literalmente un carácter, sino que tiene un significado especial para definir un patrón de búsqueda.
#
# Dicho de otra forma:
#
# * Si escribes una letra normal (ejemplo: a), la expresión regular buscará la letra a exactamente.
#
# * Pero si usas un metacaracter (ejemplo: \d), no busca la letra d, sino que significa “cualquier número del 0 al 9”.

# %% [markdown]
# **Metacaracteres mas comunes:**
#
# * ^ → Inicio de cadena
# * $ → Fin de cadena
# * . → Cualquier carácter
# * \d → Número (0-9)
# * \w → Caracter o número
# * \s → Espacio, tab, salto de línea
# * ' * → 0 o más repeticiones
# * ' + → 1 o más repeticiones
# * [abc] → a, b o c
# * [^abc] → Cualquier cosa menos a, b, c

# %% [markdown]
# ---

# %% [markdown]
# #**TEMA 03 - Programacion procedimental y Programacion Orientada a Objetos**

# %% [markdown]
# ---

# %% [markdown]
# ##**Programación procedimental**

# %% [markdown]
# > La programación procedimental es un paradigma que organiza el código en funciones o procedimientos que se ejecutan de forma secuencial.
# Los datos se procesan a través de esas funciones, pero los datos y las funciones están separados.
#
# Esto funciona muy bien en programas pequeños o medianos, pero cuando el proyecto crece y hay muchos datos y funciones, la gestión se complica. Modificar una parte puede afectar otras, lo que dificulta el mantenimiento.
#
# **Ejemplo mental:**
# * Piensa en una receta de cocina. Cada paso (función) se ejecuta uno tras otro, y los ingredientes (datos) se pasan a cada paso.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ##**Programación orientada a objetos (POO)**

# %% [markdown]
# > La programación orientada a objetos surge para solucionar esas limitaciones.
# En este paradigma, el código se organiza en objetos, que son unidades que combinan datos y comportamientos en un mismo lugar.
#
# En lugar de tener funciones separadas que trabajan sobre datos sueltos, ahora tenemos objetos que “saben” cuáles son sus datos y cómo trabajar con ellos.
#
# Esto permite una mejor organización, mayor reutilización del código y facilita mantener o ampliar programas grandes.
#
# **Ejemplo mental:**
# * Si en vez de pensar en una receta de cocina piensas en un "robot chef", el robot ya sabe cuáles son sus ingredientes (datos) y qué acciones puede hacer (métodos). No hay que pasarle todo desde fuera: el objeto “coche”, “persona” o “cuenta bancaria” ya tiene dentro lo necesario.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Diferencia clave:**
#
# > En programación procedimental: los datos y las funciones son piezas separadas que se relacionan mediante llamadas.
#
# > En programación orientada a objetos: los datos y las funciones viven juntos dentro de los objetos, lo que hace que el código sea más natural, modular y fácil de mantener.

# %% [markdown]
# ##**Objetos**

# %% [markdown]
# **¿Qué son los objetos en Python?**
#
# > En Python, todo es un objeto: números, cadenas, listas, funciones y también las instancias que creamos con nuestras propias clases.
#
# **Un objeto es una entidad que combina:**
#
# * Atributos → datos que describen al objeto.
# * Métodos → funciones que definen su comportamiento.
# ---
# **Ejemplo:**
# Un objeto de tipo str (cadena de texto) tiene atributos y métodos como .upper() o .lower().

# %%
texto = "hola"
print(texto.upper())  # "HOLA"


# Aquí, texto es un objeto de la clase str, y .upper() es un método.

# %% [markdown]
# **¿Para qué se usan?**
#
# Estos permiten:
#
# * Representar entidades del mundo real → personas, coches, cuentas, productos.
# * Agrupar datos y comportamientos en un mismo bloque (más organizado que tener funciones y variables sueltas).
# * Reutilizar código → con clases podemos crear múltiples objetos sin reescribir todo.
# * Facilitar el mantenimiento → si hay un cambio, se modifica la clase y todos los objetos lo heredan.

# %% [markdown]
# ---

# %% [markdown]
# **Ejemplo**

# %%
animals = ['lion', 'tiger', 'cat', 'dog']
animals.sort()
animals

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * La lista de animales es un objeto que tiene 'león', 'tigre', 'gato', 'perro' como elementos (atributos).
#
# * También tiene sort, append, remove, reverse, pop como funciones miembro (métodos) (llama a los métodos
# mediante una notación . (punto) )
#
# * Las funciones miembro propiedad del objeto animal se denominan métodos.
# Objeto
#
# > Como tales, los elementos del sistema informático que tienen atributos y métodos se denominan objetos.

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""
texto es un objeto de la clase str.
Tiene atributos y métodos que podemos usar directamente.
"""

texto = "python"
print(type(texto))      #  <class 'str'>
print(texto.upper())    #  convierte a MAYÚSCULAS
print(texto.replace("p", "P"))  #  reemplaza caracteres

# %% [markdown]
# #**TEMA 04 - Creacion y uso de Clases en Python**

# %% [markdown]
# Una clase en Python es un molde o plantilla que permite crear objetos.
# En la clase se definen las características (atributos) y los comportamientos (métodos) que tendrán los objetos creados a partir de ella.
#
# > Gracias a las clases podemos modelar entidades del mundo real (como personas, autos o productos) dentro de un programa, manteniendo el código más organizado, reutilizable y fácil de mantener.

# %% [markdown]
# **¿Para qué se usan las clases?**
#
# * Para agrupar datos y funciones que están relacionadas.
#
# * Para modelar entidades reales o abstractas (ejemplo: estudiantes, cuentas bancarias, jugadores en un videojuego).
#
# * Para crear múltiples objetos basados en una misma definición.
#
# * Para organizar programas grandes en piezas más manejables.

# %% [markdown]
# **Sintaxis Basica**

# %%
class NombreClase: #Definicion de la clase
    def __init__(self, parametros):
        self.atributo1 = valor
        self.atributo2 = valor

    def metodo(self):
        # Acción que realiza el objeto
        pass

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Elementos que componen una clase:**
#
# * Nombre de la clase: por convención, inicia con mayúscula (Persona, Coche).
#
# * Constructor __init__: método especial que se ejecuta al crear el objeto; inicializa atributos.
#
# * Atributos: variables propias del objeto que guardan información (ejemplo: nombre, edad, color).
#
# * Métodos: funciones definidas dentro de la clase que describen lo que el objeto puede hacer.
#
# * Objetos: instancias creadas a partir de la clase, cada uno con sus propios valores.

# %% [markdown]
# **Ejemplos:**

# %%
class Persona:
    def __init__(self, nombre, edad):
        self.nombre = nombre   # atributo
        self.edad = edad       # atributo

    def saludar(self):         # método
        print(f"Hola, soy {self.nombre} y tengo {self.edad} años.")

# %%
p1 = Persona("Ana", 25)
p2 = Persona("Luis", 30)

p1.saludar()  # Hola, soy Ana y tengo 25 años.
p2.saludar()  # Hola, soy Luis y tengo 30 años.

# %% [markdown]
# ---

# %% [markdown]
# **¿Qué es self?**
#
# self es una referencia al propio objeto que se está creando o usando.
#
# Cuando instancias una clase, cada objeto necesita almacenar sus propios datos.
#
# self permite que cada método sepa a qué objeto pertenece y pueda acceder a sus atributos (variables) y métodos (funciones dentro de la clase).
#
# .
#
# **En otras palabras:**
#
# self es el "yo" del objeto. Si creas dos coches, cada uno tiene su propio "yo" (su propia marca, color, velocidad, etc.).
#
#
# **¿Por qué siempre hay que ponerlo?**
#
# * Python no mete self automáticamente, tú lo defines en los métodos.
#
# * La primera posición en los métodos de una clase siempre corresponde a la instancia que invoca ese método.
#
# * Aunque escribas mi_coche.acelerar(20), internamente Python traduce eso a:
#
#
#       Coche.acelerar(mi_coche, 20)
#
#
#
# Es decir, el objeto mi_coche se pasa como primer argumento al método, y ese primer argumento lo llamamos self por convención.

# %%
class Coche:
    def __init__(self, marca, color):
        self.marca = marca     # ← guardo marca en este objeto
        self.color = color     # ← guardo color en este objeto
        self.velocidad = 0     # ← cada objeto empieza con velocidad 0

    def acelerar(self, cantidad):
        self.velocidad += cantidad   # ← modifico la velocidad de "este coche"
        print(f"El {self.marca} aceleró a {self.velocidad} km/h")

    def frenar(self):
        self.velocidad = 0
        print(f"El {self.marca} se detuvo")

# %%
mi_auto = Coche("Toyota", "Rojo")

mi_auto.acelerar(50)   #  El Toyota aceleró a 50 km/h
mi_auto.frenar()       #  El Toyota se detuvo

c1 = Coche("Toyota", "Rojo")
c2 = Coche("Mazda", "Azul")

c1.acelerar(30)   # afecta solo a c1
c2.acelerar(50)   # afecta solo a c2
# Out:
# El Toyota aceleró a 50 km/h
# El Toyota se detuvo
# El Toyota aceleró a 30 km/h
# El Mazda aceleró a 50 km/h

# %% [markdown]
# **¿Qué pasa si NO pongo self?**
#
# El método no tendría forma de saber a qué objeto modificar.
#
# **Ejemplo con error:**

# %%
class Coche:
    def __init__(marca, color):   # ← falta self
        marca = marca             # esto NO guarda nada en el objeto
        color = color

# %% [markdown]
# * self = referencia al objeto actual.
#
# * Se pasa automáticamente como primer argumento, pero hay que declararlo en los métodos.
#
# * Es necesario para guardar y acceder a los atributos y métodos de cada objeto.
#
# * Sin self, tus métodos no sabrían a qué instancia aplicarse.

# %% [markdown]
# ---

# %% [markdown]
# Las clases en Python permiten organizar el código siguiendo el paradigma de la programación orientada a objetos (POO).
#
# * Una clase es el molde.
#
# * Un objeto es la instancia creada a partir de la clase.
#
# * Los atributos representan datos.
#
# * Los métodos representan acciones.
#
# De esta manera, las clases hacen que los programas sean más claros, escalables y fáciles de reutilizar.

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**Clase VS Instancia**
# **Clase**
# * Conjunto de atributos y acciones utilizados en los programas.
# * Plano, plantilla o esquema de objetos.
#
# **Instancia**
# * Objeto individual creado a partir de una clase.
# * Diferentes instancias pueden tener diferentes valores de atributo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Constructores en Python**

# %% [markdown]
# ###**Metodo __init __**

# %% [markdown]
# Un constructor es un método especial dentro de una clase que se encarga de crear e inicializar un objeto.
# En Python, ese constructor se llama __init __.
#
# **Cuando escribimos:**
#
#      objeto = Clase(parametros)
#
# Python automáticamente llama al método __init__ de esa clase, pasando los valores que le damos como parámetros.

# %% [markdown]
# **¿Para qué sirven los constructores?**
#
# * **Inicializar los atributos del objeto:** Al momento de crear un objeto, el constructor permite asignarle valores iniciales (nombre, edad, color, etc.).
#
# * **Ahorrar código repetitivo:** En lugar de tener que asignar atributos uno por uno después de crear el objeto, el constructor lo hace todo en un solo paso.
#
# * **Garantizar consistencia:** Gracias al constructor, sabemos que todo objeto creado tendrá los atributos necesarios, evitando errores.
#
# * **Dar valores por defecto:** Se pueden establecer valores predeterminados para los atributos, en caso de que no se proporcionen.

# %%
"""
Cuando escribimos Persona("Ana", 25), Python crea un objeto de tipo Persona.
Luego ejecuta el constructor __init__ y guarda "Ana" y 25 dentro de los atributos nombre y edad.

"""

class Persona:
    def __init__(self, nombre, edad):
        self.nombre = nombre   # atributo inicializado
        self.edad = edad       # atributo inicializado

# Crear objetos usando el constructor
p1 = Persona("Ana", 25)
p2 = Persona("Luis", 30)

print(p1.nombre, p1.edad)  # Ana 25
print(p2.nombre, p2.edad)  # Luis 30
# Out:
# Ana 25
# Luis 30

# %% [markdown]
# **¿Por qué se usan los constructores?**
#
# * Porque permiten crear objetos completos desde el inicio.
#
# * Porque hacen que el código sea más ordenado y claro.
#
# * Porque son una de las bases de la Programación Orientada a Objetos (POO) ya que ayudan a que cada objeto tenga su propia identidad desde el momento en que nace.

# %%
class Gato:
    def __init__(self, nombre="Michi", color="Gris"):
        self.nombre = nombre
        self.color = color

g1 = Gato()                     # Usa los valores por defecto
g2 = Gato("Pelusa", "Blanco")   # Usa valores personalizados

print(g1.nombre, g1.color)  # Michi Gris
print(g2.nombre, g2.color)  # Pelusa Blanco
# Out:
# Michi Gris
# Pelusa Blanco

# %% [markdown]
# ###**Metodo __str __**

# %% [markdown]
# El método __str__ es un método especial en Python que define cómo se debe mostrar un objeto en forma de texto.
#
# En otras palabras, permite que cuando hagamos print(objeto) veamos información clara y legible, en lugar de un mensaje técnico como:

# %%
<__main__.Clase object at 0x000001F4>

# %% [markdown]
# **¿Para qué sirve __str __?**
#
# * Hacer más legible la información de un objeto: En vez de ver direcciones de memoria, obtenemos una descripción con sentido.
#
# * Facilitar la depuración (debugging) : Si un programa imprime objetos en la consola, __str __ nos ayuda a saber qué contiene cada objeto.
#
# * Personalizar la representación textual: Tú decides qué atributos mostrar y cómo se verán.
#
# **¿Por qué se usa __str __?**
#
# * Porque sin él, Python no sabe cómo mostrar el objeto de manera entendible.
#
# * Porque permite representar al objeto en forma de cadena (texto) de la manera que nosotros necesitemos.
#
# * Porque mejora la experiencia de lectura cuando trabajamos con muchos objetos.

# %% [markdown]
# **SINTAXIS**

# %%
def __str__(self):
    return "Texto que represente al objeto"

"""
Siempre debe devolver un string (str).
Dentro del string podemos incluir atributos del objeto.
"""

# %% [markdown]
# **Ejemplo**

# %%
class Persona:
    def __init__(self, nombre, edad):
        self.nombre = nombre
        self.edad = edad

    def __str__(self):
        return f"Persona: {self.nombre}, Edad: {self.edad}"

# %%
p1 = Persona("Ana", 25)
p2 = Persona("Luis", 30)

print(p1)  # Persona: Ana, Edad: 25
print(p2)  # Persona: Luis, Edad: 30

# Gracias a __str__, cuando imprimimos p1 o p2, Python no muestra la dirección de memoria, sino un texto claro.

# %% [markdown]
# ---

# %%
class Coche:
    def __init__(self, marca, color):
        self.marca = marca
        self.color = color

    def __str__(self):
        return f"Coche {self.marca} de color {self.color}"

# %%
auto1 = Coche("Toyota", "Rojo")
auto2 = Coche("Nissan", "Azul")

print(auto1)  # Coche Toyota de color Rojo
print(auto2)  # Coche Nissan de color Azul
# Out:
# Coche Toyota de color Rojo
# Coche Nissan de color Azul

# %% [markdown]
# ---
#
# .
#
# **Diferencia entre __init __ y __str __ :**
#
# > __init __ → Sirve para crear e inicializar el objeto.
#
# > __str __ → Sirve para mostrar el objeto como un texto entendible.

# %% [markdown]
# ---

# %% [markdown]
# #**TEMA 05 - Variables de Instancia, Clase, Miembro Y Campo**

# %% [markdown]
# Cuando trabajamos con Programación Orientada a Objetos (POO), los atributos (variables) pueden ser de distintos tipos.

# %% [markdown]
# ##**Variables de instancia**

# %% [markdown]
# * Son las más comunes.
# * Pertenecen a cada objeto en particular.
# * Se definen dentro del constructor __init __ con self.
# * Cada instancia tiene sus propios valores independientes.

# %%
class Gato:
    def __init__(self, nombre, color):
        self.nombre = nombre   # variable de instancia
        self.color = color     # variable de instancia

nabi = Gato("Nabi", "Negro")
nero = Gato("Nero", "Blanco")

print(nabi.nombre)  # Nabi
print(nero.nombre)  # Nero

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Variables de clase**

# %% [markdown]
# * Son compartidas por todas las instancias de la clase.
# * Se definen fuera del __init __, directamente dentro de la clase.
# * Cambiar su valor desde la clase afecta a todos los objetos.

# %%
class Gato:
    especie = "Felino"   # variable de clase

    def __init__(self, nombre, color):
        self.nombre = nombre
        self.color = color

nabi = Gato("Nabi", "Negro")
nero = Gato("Nero", "Blanco")

print(nabi.especie)  # Felino
print(nero.especie)  # Felino

# Aquí, especie es la misma para todos los gatos, porque es una variable de clase.

# %% [markdown]
# ##**Variables Miembro**

# %% [markdown]
# El término variable miembro se refiere de manera general a cualquier variable asociada a una clase u objeto.
#
# Por eso puede englobar tanto a las variables de instancia como a las variables de clase.
#
# **En pocas palabras:**
#
# > Variables miembro = atributos de la clase u objetos.

# %% [markdown]
# ##**Campos**

# %% [markdown]
# El término campo es otro sinónimo muy usado para hablar de atributos en POO.
#
# Al igual que “variable miembro”, hace referencia a los datos que pertenecen a una clase u objeto.
#
# Ejemplo: en la clase Gato, los campos son nombre y color.

# %% [markdown]
# # **TEMA 06 - Encapsulacion en clases**

# %% [markdown]
# La encapsulación es un principio de la programación orientada a objetos (POO) que consiste en proteger los atributos y métodos de una clase para que no sean accedidos o modificados directamente desde fuera del objeto.
#
# Esto se hace para garantizar que los datos siempre tengan valores válidos y que la interacción con ellos se haga de forma controlada.
#
# **En Python se utiliza principalmente:**
#
# Convención de nombres:
#
# * _atributo (protegido, acceso interno preferido).
#
# * __atributo (privado, fuertemente restringido).
#
# Estos son métodos especiales llamados **getters y setters** para leer y modificar estos atributos de forma segura.

# %% [markdown]
# * Un getter es un método que devuelve el valor de un atributo.
#
# * Un setter es un método que asigna un valor a un atributo, pero puede incluir validaciones.
#
# * Evita modificar atributos de manera directa que podría romper la lógica interna.
#
# * Permite controlar qué valores son aceptados o no.

# %% [markdown]
# **Sintaxis / Estructura**

# %%
class ClaseEjemplo:
    def __init__(self, valor):
        self.__atributo = valor   # atributo privado

    # Getter
    def get_atributo(self):
        return self.__atributo

    # Setter
    def set_atributo(self, nuevo_valor):
        if nuevo_valor > 0:
            self.__atributo = nuevo_valor

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Ejemplos**

# %%
class CuentaBancaria:
    def __init__(self, saldo):
        self.__saldo = saldo   # encapsulado

    def depositar(self, cantidad):
        self.__saldo += cantidad

    def mostrar_saldo(self):
        return self.__saldo

c1 = CuentaBancaria(100)
c1.depositar(50)
print(c1.mostrar_saldo())  # 150

# %% [markdown]
# **Con getter y setter**

# %%
class CuentaBancaria:
    def __init__(self, saldo):
        self.__saldo = saldo   # atributo encapsulado

    def depositar(self, cantidad):
        if cantidad > 0:
            self.__saldo += cantidad

    def get_saldo(self):   # getter
        return self.__saldo

    def set_saldo(self, nuevo_saldo):   # setter con validación
        if nuevo_saldo >= 0:
            self.__saldo = nuevo_saldo

c1 = CuentaBancaria(100)
c1.depositar(50)
print(c1.get_saldo())  # 150
c1.set_saldo(200)
print(c1.get_saldo())  # 200

# %% [markdown]
# ---

# %%
class Persona:
    def __init__(self, nombre):
        self.__nombre = nombre

    def get_nombre(self):
        return self.__nombre

    def set_nombre(self, nuevo):
        self.__nombre = nuevo

p = Persona("Ana")
print(p.get_nombre())   # Ana
p.set_nombre("Luis")
print(p.get_nombre())   # Luis

# %% [markdown]
# ---

# %% [markdown]
# **Ejemplo del gato con getter y setter**

# %%
class Gato:
    def __init__(self, nombre, edad):
        self._nombre = nombre   # atributo protegido
        self._edad = edad       # atributo protegido

    # Getter de edad
    def get_edad(self):
        return self._edad

    # Setter de edad con validación
    def set_edad(self, edad):
        if edad > 0:
            self._edad = edad
        else:
            print("La edad debe ser un número positivo.")

# Uso
g1 = Gato("Mimi", 2)
print(g1.get_edad())   # 2

print('+'*16)

g1.set_edad(5)         # actualizar edad
print(g1.get_edad())   # 5

print('+'*16)

g1.set_edad(-3)        # intento inválido, La edad debe ser un número positivo

# %% [markdown]
# ---

# %% [markdown]
# **¿Por qué es útil?**
#
# * Evita errores por manipular datos directamente.
#
# * Permite mayor control y seguridad.
#
# * Facilita el mantenimiento y evolución del código.
#
# * Mantiene los datos seguros frente a modificaciones indebidas.
#
# * Permite agregar validaciones y reglas de negocio antes de modificar atributos.
#
# * Hace que el código sea más robusto y confiable.

# %% [markdown]
# # **TEMA 07 - Herencia en clases**

# %% [markdown]
# La herencia permite que una clase (llamada subclase o clase hija) herede atributos y métodos de otra clase (llamada superclase o clase padre).
#
# Es uno de los pilares de la POO y sirve para reutilizar código y modelar relaciones jerárquicas.
#
#
# ---
# .
# * Permite crear nuevas clases a partir de clases existentes.
#
# * La clase hija hereda atributos y métodos de la clase padre.
#
# * Se pueden sobrescribir (override) métodos para cambiar su comportamiento.
#
# * Se logra usando paréntesis con el nombre de la clase padre.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Sintaxis / Estructura**

# %%
class ClasePadre:
    def metodo_padre(self):
        pass

class ClaseHija(ClasePadre):
    def metodo_hija(self):
        pass

# %% [markdown]
# **Ejemplos**

# %%
class Animal:
    def __init__(self, nombre):
        self.nombre = nombre

    def hablar(self):
        print("Hace un sonido")

class Perro(Animal):
    def hablar(self):   # sobrescritura
        print("Guau!")

p = Perro("Firulais")
p.hablar()  # Guau!
# Out:
# Guau!

# %% [markdown]
# ---

# %%
class Vehiculo:
    def __init__(self, marca):
        self.marca = marca

class Coche(Vehiculo):
    def __init__(self, marca, color):
        super().__init__(marca)   # herencia del constructor
        self.color = color

auto = Coche("Toyota", "Rojo")
print(auto.marca, auto.color)  # Toyota Rojo

# %% [markdown]
# **¿Por qué es útil?**
#
# * Permite reutilizar código.
#
# * Facilita la organización en jerarquías.
#
# * Ayuda a implementar polimorfismo (un mismo método se comporta diferente según la clase).

# %% [markdown]
# # **TEMA 08 - Jerarquia en clases**

# %% [markdown]
# Una jerarquía de clases es la organización de clases en niveles, donde las clases más generales están arriba y las más específicas abajo.
#
# Se construye mediante herencia múltiple o simple, creando un árbol de relaciones.
#
# * Permite representar relaciones de tipo “es un” (ejemplo: un perro es un animal).
#
# * Se organiza desde lo más genérico (superclase) hasta lo más específico (subclases).
#
# * Favorece el reuso y extensión del código.
#
# * Es común en sistemas grandes con múltiples entidades.

# %% [markdown]
# **Sintaxis / Estructura**

# %%
class SuperClase:
    pass

class SubClase(SuperClase):
    pass

class SubSubClase(SubClase):
    pass

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Ejemplos**

# %%
class Animal:
    pass

class Mamifero(Animal):
    pass

class Perro(Mamifero):
    pass

mi_perro = Perro()
print(isinstance(mi_perro, Animal))   # True

# %% [markdown]
# ---

# %%
class Empleado:
    def __init__(self, nombre):
        self.nombre = nombre

class Gerente(Empleado):
    def mostrar(self):
        print(f"Soy {self.nombre}, un gerente.")

class Programador(Empleado):
    def mostrar(self):
        print(f"Soy {self.nombre}, un programador.")

g = Gerente("Ana")
p = Programador("Luis")

g.mostrar()  # Soy Ana, un gerente.
p.mostrar()  # Soy Luis, un programador.

# %% [markdown]
# **¿Por qué es útil?**
#
# * Permite organizar el sistema en niveles.
#
# * Favorece el reuso de código y claridad en relaciones.
#
# * Refleja el mundo real en una estructura más entendible.

# %% [markdown]
# #**TEMA 09 - METODOS ESPECIALES**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
